# %%
# https://www.datacamp.com/community/tutorials/pandas-split-apply-combine-groupby
# good explain on groupby
# idea about split - apply - combine
# need to prepare good data for easier to understand

# %%
import pandas as pd
df_imdb= pd.read_csv('./data/IMDB_Movie_Facebook_Like.csv')
df_imdb.sort_values('movie_facebook_likes', ascending=False).head()
# Out:
#              director_name                          movie_title  \
# 96       Christopher Nolan                        Interstellar
# 296      Quentin Tarantino                    Django Unchained
# 10             Zack Snyder  Batman v Superman: Dawn of Justice
# 128          George Miller                  Mad Max: Fury Road
# 179  Alejandro G. Iñárritu                        The Revenant
#
#      movie_facebook_likes
# 96                 349000
# 296                199000
# 10                 197000
# 128                191000
# 179                190000

# %% [markdown]
# # Director with most social network facebook likes

# %%
df_fb_likes.groupby('director_name').sum().sort_values('movie_facebook_likes', ascending=False).head()
# Out:
#                    movie_facebook_likes
# director_name
# Christopher Nolan                829000
# Ridley Scott                     492911
# Steven Spielberg                 446000
# Quentin Tarantino                432000
# David Fincher                    421000

# %%
df_imdb[df_imdb['director_name']=='Christopher Nolan'].head()
# df_imdb[df_imdb['director_name']=='Ridley Scott'].head()
# Out:
#      color      director_name  num_critic_for_reviews  duration  \
# 3    Color  Christopher Nolan                   813.0     164.0
# 66   Color  Christopher Nolan                   645.0     152.0
# 96   Color  Christopher Nolan                   712.0     169.0
# 97   Color  Christopher Nolan                   642.0     148.0
# 120  Color  Christopher Nolan                   478.0     128.0
#
#      director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 3                    22000.0                 23000.0  Christian Bale
# 66                   22000.0                 11000.0    Heath Ledger
# 96                   22000.0                  6000.0   Anne Hathaway
# 97                   22000.0                 23000.0       Tom Hardy
# 120                  22000.0                 11000.0     Liam Neeson
#
#      actor_1_facebook_likes        gross                            genres  \
# 3                   27000.0  448130642.0                   Action|Thriller
# ...
